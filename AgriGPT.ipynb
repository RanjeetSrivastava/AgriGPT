# %% [markdown]
# <a href="https://colab.research.google.com/github/RanjeetSrivastava/AgriGPT/blob/main/AgriGPT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install datasets kaggle wikipedia-api
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 15.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.4/108.4 kB 12.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.3.3
#     Uninstalling click-8.3.3:
#       Successfully uninstalled click-8.3.3
# ...

# %%
from datasets import load_dataset
dataset = load_dataset("iamtarun/agriculture_data")
print(dataset)
print(dataset['train'][0])
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ---------------------------------------------------------------------------
# DatasetNotFoundError                      Traceback (most recent call last)
# /tmp/ipykernel_809/321952858.py in <cell line: 0>()
#       1 from datasets import load_dataset
# ----> 2 dataset = load_dataset("iamtarun/agriculture_data")
#       3 print(dataset)
#       4 print(dataset['train'][0])
#
# ...

# %%
# !pip install datasets -q
from datasets import load_dataset, concatenate_datasets

# %%
ds1 = load_dataset("KisanVaani/agriculture-qa-english-only")
print("KisanVaani loaded:", ds1)
print("Sample:", ds1['train'][0])
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/1.97M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/22615 [00:00<?, ? examples/s]
# KisanVaani loaded: DatasetDict({
#     train: Dataset({
#         features: ['question', 'answers'],
# ...

# %%
ds2 = load_dataset("YuvrajSingh9886/Agriculture-Soil-QA-Pairs-Dataset")
print("Soil QA loaded:", ds2)
# Out:
# qna-dataset-farmgenie-soil-v2.csv: 0.00B [00:00, ?B/s]
# Generating train split:   0%|          | 0/3447 [00:00<?, ? examples/s]
# Soil QA loaded: DatasetDict({
#     train: Dataset({
#         features: ['Unnamed: 0', 'ANSWER', 'QUESTION.question', 'QUESTION.paragraph'],
#         num_rows: 3447
#     })
# })

# %%
ds3 = load_dataset("YuvrajSingh9886/Agriculture-Irrigation-QA-Pairs-Dataset")
print("Irrigation QA loaded:", ds3)
# Out:
# (…)ataset-farmgenie-water-irrigation-v2.csv: 0.00B [00:00, ?B/s]
# Generating train split:   0%|          | 0/3851 [00:00<?, ? examples/s]
# Irrigation QA loaded: DatasetDict({
#     train: Dataset({
#         features: ['Unnamed: 0', 'ANSWER', 'QUESTION.question', 'QUESTION.paragraph'],
#         num_rows: 3851
#     })
# })

# %%
import os
base = '/content/drive/MyDrive/krishibot/data/raw_text'
os.makedirs(base, exist_ok=True)

ds1.save_to_disk(f'{base}/kisanvaani')
ds2.save_to_disk(f'{base}/soil_qa')
ds3.save_to_disk(f'{base}/irrigation_qa')
print("✅ All text datasets saved to Drive!")
# Out:
# ...
# Saving the dataset (0/1 shards):   0%|          | 0/3851 [00:00<?, ? examples/s]
# ✅ All text datasets saved to Drive!

# %%
# VERIFIED — Correct PlantVillage dataset name
from datasets import load_dataset

# This is the confirmed working ID
plant_data = load_dataset("mohanty/PlantVillage", "color")
print(plant_data)
# Expected output:
# DatasetDict({
#   train: Dataset({num_rows: 43596})
#   test:  Dataset({num_rows: 10709})
# })

# Save to Drive
plant_data.save_to_disk('/content/drive/MyDrive/krishibot/data/raw_images/plantvillage')
print("PlantVillage saved!")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_268/4154167277.py in <cell line: 0>()
#       3
#       4 # This is the confirmed working ID
# ----> 5 plant_data = load_dataset("mohanty/PlantVillage", "color")
#       6 print(plant_data)
#       7 # Expected output:
#
# /usr/local/lib/python3.12/dist-packages/datasets/load.py in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1390
#    1391     # Create a dataset builder
# -> 1392     builder_instance = load_dataset_builder(
#    1393         path=path,
#    1394         name=name,
#
# ...

# %%
from datasets import load_dataset

# %%
plant_data = load_dataset("mohanty/PlantVillage", "default")
print(plant_data)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text'],
#         num_rows: 129783
#     })
#     test: Dataset({
#         features: ['text'],
#         num_rows: 33133
#     })
# })

# %%
plant_data.save_to_disk('/content/drive/MyDrive/krishibot/data/raw_images/plantvillage')
print("✅ PlantVillage saved!")
# Out:
# ...
# Saving the dataset (0/1 shards):   0%|          | 0/33133 [00:00<?, ? examples/s]
# ✅ PlantVillage saved!

# %%
leafnet = load_dataset("enalis/LeafNet")
leafnet.save_to_disk('/content/drive/MyDrive/krishibot/data/raw_images/leafnet')
# Out:
# ---------------------------------------------------------------------------
# DatasetNotFoundError                      Traceback (most recent call last)
# /tmp/ipykernel_268/1936667045.py in <cell line: 0>()
# ----> 1 leafnet = load_dataset("enalis/LeafNet")
#       2 leafnet.save_to_disk('/content/drive/MyDrive/krishibot/data/raw_images/leafnet')
#
# /usr/local/lib/python3.12/dist-packages/datasets/load.py in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1390
#    1391     # Create a dataset builder
# -> 1392     builder_instance = load_dataset_builder(
#    1393         path=path,
#    1394         name=name,
#
# ...

# %% [markdown]
# ### Hugging Face Authentication
#
# To access gated datasets or upload to the Hugging Face Hub, you need to provide an authentication token. You can generate a token from your [Hugging Face settings page](https://huggingface.co/settings/tokens).
#
# Once you have your token, add it to Colab's secrets manager (the '🔑' icon on the left panel) with the name `HF_TOKEN`. Then, run the following cell to make it available to your environment.

# %%
# Used to securely store your API key
from google.colab import userdata
import os

# Get the HF_TOKEN from Colab secrets
hf_token = userdata.get('HF_TOKEN')

# Set the token as an environment variable
os.environ['HF_TOKEN'] = hf_token

print("✅ Hugging Face token loaded and set as environment variable.")
# Out:
# ✅ Hugging Face token loaded and set as environment variable.

# %%
# Optional but recommended — larger, more diverse dataset
leafnet = load_dataset("enalis/LeafNet")
leafnet.save_to_disk('/content/drive/MyDrive/krishibot/data/raw_images/leafnet')
# Out:
# data/train-00000-of-00007.parquet:   0%|          | 0.00/706M [00:00<?, ?B/s]
# data/train-00001-of-00007.parquet:   0%|          | 0.00/638M [00:00<?, ?B/s]
# data/train-00002-of-00007.parquet:   0%|          | 0.00/516M [00:00<?, ?B/s]
# data/train-00003-of-00007.parquet:   0%|          | 0.00/1.74G [00:00<?, ?B/s]
# data/train-00004-of-00007.parquet:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# data/train-00005-of-00007.parquet:   0%|          | 0.00/1.41G [00:00<?, ?B/s]
# data/train-00006-of-00007.parquet:   0%|          | 0.00/1.57G [00:00<?, ?B/s]
# ...
# Saving the dataset (0/18 shards):   0%|          | 0/121337 [00:00<?, ? examples/s]

# %%
# Safe way to preview any HuggingFace dataset without full download
from datasets import load_dataset

# streaming=True lets you look without downloading everything
preview = load_dataset("mohanty/PlantVillage", "default", streaming=True)
sample = next(iter(preview['train']))
print(sample)  # See one row — confirm structure before committing
# Out:
# {'text': 'raw/color/Raspberry___healthy/a37f34f7-022d-461a-8a3d-95f5cd774e35___Mary_HL 9155.JPG'}

# %%
from PIL import Image
import matplotlib.pyplot as plt
import os

# Extract the relative image path from the sample
relative_image_path = sample['text']

# Construct the full path to the dataset on Google Drive
# Note: This path points to where the dataset *metadata* is saved.
# The 'mohanty/PlantVillage' dataset (default config) stores image *paths* as text,
# not the actual image files themselves. Therefore, trying to open a local file
# using these paths will result in a FileNotFoundError unless the images were
# downloaded separately and placed in the corresponding structure.
# dataset_base_path = '/content/drive/MyDrive/krishibot/data/raw_images/plantvillage/train'
# full_image_path = os.path.join(dataset_base_path, relative_image_path)

print(f"The sample indicates a path: {relative_image_path}")
print("However, the 'mohanty/PlantVillage' dataset (default config) provides image *paths* within a 'text' feature,")
print("not the actual image *files*. Therefore, these images were not downloaded or saved to disk by `load_dataset` or `save_to_disk`.")
print("To display the images, you would need to:")
print("1. Find a Hugging Face dataset for PlantVillage that provides an 'Image' feature directly.")
print("2. Manually download the original PlantVillage image dataset and use these 'text' paths to access the corresponding local files.")
# The following code is commented out as it will always result in FileNotFoundError for this dataset structure.
# try:
#     img = Image.open(full_image_path)
#     plt.imshow(img)
#     plt.title(f"Image from PlantVillage: {relative_image_path.split('/')[-1]}")
#     plt.axis('off')
#     plt.show()
# except FileNotFoundError:
#     print(f"Error: Image file not found at {full_image_path}")
#     print("Please ensure the dataset was saved correctly and the path is accurate.")
# except Exception as e:
#     print(f"An error occurred: {e}")
# Out:
# Error: Image file not found at /content/drive/MyDrive/krishibot/data/raw_images/plantvillage/train/raw/color/Raspberry___healthy/a37f34f7-022d-461a-8a3d-95f5cd774e35___Mary_HL 9155.JPG
# Please ensure the dataset was saved correctly and the path is accurate.

# %%
# Cell 4: Download PlantVillage disease images
from datasets import load_dataset

# Removed 'nelorth/oxford-flowers' as it was for a test run and not directly related to PlantVillage
# Updated PlantVillage dataset name to the correct 'mohanty/PlantVillage' and explicitly setting config to 'default'
plant_data = load_dataset("mohanty/PlantVillage", "default")  # main dataset
print(plant_data)

# Cell 5: Save images
plant_data.save_to_disk('/content/drive/MyDrive/krishibot/data/raw_images/plantvillage')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_268/2098133031.py in <cell line: 0>()
#       4 # Removed 'nelorth/oxford-flowers' as it was for a test run and not directly related to PlantVillage
#       5 # Updated PlantVillage dataset name to the correct 'mohanty/PlantVillage'
# ----> 6 plant_data = load_dataset("mohanty/PlantVillage")  # main dataset
#       7 print(plant_data)
#       8
#
# /usr/local/lib/python3.12/dist-packages/datasets/load.py in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1390
#    1391     # Create a dataset builder
# -> 1392     builder_instance = load_dataset_builder(
#    1393         path=path,
#    1394         name=name,
#
# ...

# %%
# PlantDoc is on GitHub — clone it
# !git clone https://github.com/pratikkayal/PlantDoc-Dataset.git
# !cp -r PlantDoc-Dataset /content/drive/MyDrive/krishibot/data/plantdoc
# Out:
# Cloning into 'PlantDoc-Dataset'...
# remote: Enumerating objects: 2670, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 2670 (delta 22), reused 22 (delta 22), pack-reused 2635 (from 1)
# Receiving objects: 100% (2670/2670), 932.92 MiB | 33.92 MiB/s, done.
# Resolving deltas: 100% (24/24), done.
# Updating files: 100% (2581/2581), done.

# %%
# Cell 6: Test Open-Meteo free weather API (no key needed!)
import requests

def get_weather(lat, lon, district_name):
    url = f"https://api.open-meteo.com/v1/forecast"
    params = {
        "latitude": lat, "longitude": lon,
        "daily": ["temperature_2m_max", "precipitation_sum", "windspeed_10m_max"],
        "timezone": "Asia/Kolkata", "forecast_days": 7
    }
    r = requests.get(url, params=params)
    return r.json()

# Test with Bangalore coordinates
weather = get_weather(12.97, 77.59, "Bangalore")
print(weather['daily'])
# Out:
# {'time': ['2026-05-25', '2026-05-26', '2026-05-27', '2026-05-28', '2026-05-29', '2026-05-30', '2026-05-31'], 'temperature_2m_max': [30.1, 31.0, 30.4, 30.5, 30.9, 30.1, 28.5], 'precipitation_sum': [9.6, 6.8, 5.0, 4.4, 3.0, 3.6, 1.2], 'windspeed_10m_max': [15.3, 14.7, 10.9, 12.9, 11.6, 12.8, 19.1]}

# %%
# Cell 7: Install IndicTrans2
# !pip install indic-transliteration
# !git clone https://github.com/AI4Bharat/IndicTrans2.git

# You'll translate like this (run after data is collected):
# english_qa -> hindi_qa
# english_qa -> kannada_qa
# english_qa -> tamil_qa
# Then combine all into one big multilingual dataset
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.9/162.9 kB 6.5 MB/s eta 0:00:00
# ...
# Cloning into 'IndicTrans2'...
# remote: Enumerating objects: 771, done.
# remote: Counting objects: 100% (317/317), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 771 (delta 276), reused 219 (delta 219), pack-reused 454 (from 1)
# Receiving objects: 100% (771/771), 4.12 MiB | 9.80 MiB/s, done.
# Resolving deltas: 100% (510/510), done.

# %%
import os
base = '/content/drive/MyDrive/krishibot'
for folder in ['data/raw_text','data/raw_images','data/weather',
               'data/processed','data/final','notebooks','models']:
    os.makedirs(f'{base}/{folder}', exist_ok=True)
print("Folder structure created!")
# Out:
# Folder structure created!

# %% [markdown]
# After running the cell above, you can retry loading the 'enalis/LeafNet' dataset or any other gated dataset.
